# %%
import astropy.io.ascii as ascii
import numpy as np
from PIL import Image
import requests
from io import BytesIO
import astropy.visualization as viz
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import astropy.wcs as WCS # you need this astropy module for processing fits files
import matplotlib as mpl
import numpy as np
import tqdm
from astropy.table import Table, join
# %matplotlib inline
from scipy.ndimage import interpolation

# %%
image_address = "http://s3.amazonaws.com/zoo2/98.jpg"

# %%
response = requests.get(image_address)
img = Image.open(BytesIO(response.content))
red, green, blue = img.split()
plt.imshow(green, cmap='Greys')
plt.show()

# %%
grrot = interpolation.rotate(green, 45)
grrot_crop = grrot[int(grrot.shape[0]/2-424/2):int(grrot.shape[0]/2+424/2), int(grrot.shape[1]/2-424/2): int(grrot.shape[1]/2+424/2)]

# %%
plt.imshow(grrot_crop, cmap='Greys')
plt.show()

# %%
print(np.max(grrot_crop))
# Out:
# 157

# %%
grrot_crop.dtype
# Out:
# dtype('uint8')

# %%
test = np.zeros([10, 20])

# %%
list1 = []
for i in np.arange(10):
    response = requests.get(image_address)
    img = Image.open(BytesIO(response.content))
    list1.append(img)

# %%
list1[0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=424x424 at 0x10D9C74E0>
